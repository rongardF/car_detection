# %%
from ultralytics import YOLO  # Import YOLO model from Ultralytics

import cv2                   # Import OpenCV library
import math                  # Import math module for mathematical operations

# Start webcam
cap = cv2.VideoCapture(0)    # Open default camera (index 0)
cap.set(3, 640)               # Set frame width to 640 pixels
cap.set(4, 480)               # Set frame height to 480 pixels

# Load the YOLO model
model = YOLO("yolo-Weights/yolov8n.pt")  # Load YOLOv8 model with pre-trained weights

# Define object classes for detection
classNames = [
    "person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
    "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
    "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
    "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
    "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
    "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
    "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
    "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
    "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
    "teddy bear", "hair drier", "toothbrush"
]


# Infinite loop to continuously capture frames from the camera
while True:
    # Read a frame from the camera
    success, img = cap.read()

    # Perform object detection using the YOLO model on the captured frame
    results = model(img, stream=True)

    # Iterate through the results of object detection
    for r in results:
        boxes = r.boxes  # Extract bounding boxes for detected objects

        # Iterate through each bounding box
        for box in boxes:
            # Extract coordinates of the bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convert to integer values

            # Draw the bounding box on the frame
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # Calculate and print the confidence score of the detection
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->", confidence)

            # Determine and print the class name of the detected object
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Draw text indicating the class name on the frame
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    # Display the frame with detected objects in a window named "Webcam"
    cv2.imshow('Cam', img)

    # Check for the 'q' key press to exit the loop
    if cv2.waitKey(1) == ord('q'):
        break

# Release the camera
cap.release()

# Close all OpenCV windows
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolo-Weights/yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 11.0MB/s]
# 0: 480x640 1 person, 44.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 14.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.9ms preprocess, 32.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.9ms preprocess, 29.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 28.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.7ms preprocess, 28.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.8ms preprocess, 30.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.1ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.9ms preprocess, 30.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.9ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.9ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 30.1ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.9ms preprocess, 30.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 31.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.8ms preprocess, 31.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.8ms preprocess, 22.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.8ms preprocess, 20.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.7ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.7ms preprocess, 20.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 31.8ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.9ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.6ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.8ms preprocess, 29.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.8ms preprocess, 29.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.7ms preprocess, 29.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 32.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 28.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Speed: 0.9ms preprocess, 28.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.7ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.8ms preprocess, 31.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 23.4ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.9ms preprocess, 23.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 30.9ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.37
# Class name --> chair
# Speed: 0.8ms preprocess, 30.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 23.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.7ms preprocess, 23.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 21.1ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.32
# Class name --> chair
# Speed: 0.7ms preprocess, 21.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.8ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 23.9ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.29
# Class name --> chair
# Speed: 0.8ms preprocess, 23.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.4ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.8ms preprocess, 22.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.7ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.8ms preprocess, 22.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.7ms preprocess, 21.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.8ms preprocess, 20.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.7ms preprocess, 21.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 24.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.8ms preprocess, 24.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.7ms preprocess, 21.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 29.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.9ms preprocess, 29.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 28.9ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.8ms preprocess, 28.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.7ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 29.1ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 0.9ms preprocess, 29.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.8ms preprocess, 29.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 29.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 30.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.9ms preprocess, 30.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 23.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.8ms preprocess, 23.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.9ms preprocess, 31.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 23.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.7ms preprocess, 23.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.7ms preprocess, 21.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.8ms preprocess, 21.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 24.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.7ms preprocess, 24.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 23.5ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.7ms preprocess, 23.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.7ms preprocess, 21.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 23.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.8ms preprocess, 23.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.8ms preprocess, 29.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.3ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.8ms preprocess, 29.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.9ms preprocess, 29.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.8ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.9ms preprocess, 29.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.2ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.8ms preprocess, 29.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.4ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.8ms preprocess, 29.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.3ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.8ms preprocess, 31.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 29.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.9ms preprocess, 29.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.9ms preprocess, 30.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.8ms preprocess, 29.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.8ms preprocess, 29.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.7ms preprocess, 31.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 29.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.9ms preprocess, 29.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 29.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.8ms preprocess, 29.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 26.4ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.7ms preprocess, 26.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 20.8ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.5
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.7ms preprocess, 20.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 29.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.5
# Class name --> bottle
# Speed: 0.9ms preprocess, 29.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 29.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> chair
# Speed: 0.8ms preprocess, 29.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 30.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> chair
# Speed: 0.7ms preprocess, 30.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 26.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.59
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 0.7ms preprocess, 26.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 29.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.4
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.8ms preprocess, 29.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.53
# Class name --> bottle
# Confidence ---> 0.44
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> chair
# Speed: 0.9ms preprocess, 29.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 31.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.45
# Class name --> bottle
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.8ms preprocess, 31.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.4
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> chair
# Speed: 0.8ms preprocess, 29.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 29.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 32.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.61
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.8ms preprocess, 32.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 29.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> chair
# Speed: 0.8ms preprocess, 29.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.55
# Class name --> chair
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 23.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.56
# Class name --> bottle
# Confidence ---> 0.4
# Class name --> chair
# Speed: 0.7ms preprocess, 23.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 21.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.53
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.7ms preprocess, 21.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 21.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.35
# Class name --> bottle
# Speed: 0.8ms preprocess, 21.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 21.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.48
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> bottle
# Speed: 0.9ms preprocess, 21.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 21.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.48
# Class name --> bottle
# Confidence ---> 0.44
# Class name --> chair
# Confidence ---> 0.34
# Class name --> bottle
# Speed: 0.7ms preprocess, 21.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 22.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> bottle
# Speed: 0.7ms preprocess, 22.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 29.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> chair
# Speed: 0.9ms preprocess, 29.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 27.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.57
# Class name --> bottle
# Confidence ---> 0.48
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.7ms preprocess, 27.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 28.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.59
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.8ms preprocess, 28.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 29.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> bottle
# Speed: 0.7ms preprocess, 29.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 29.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.5
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 0.9ms preprocess, 29.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 30.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.5
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 0.9ms preprocess, 30.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 29.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.63
# Class name --> bottle
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 31.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.56
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> chair
# Confidence ---> 0.29
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.7ms preprocess, 31.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 29.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.55
# Class name --> bottle
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 31.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.48
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.8ms preprocess, 31.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.56
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> chair
# Confidence ---> 0.33
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 29.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.7ms preprocess, 29.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 29.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 30.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.48
# Class name --> bottle
# Confidence ---> 0.44
# Class name --> bottle
# Speed: 0.9ms preprocess, 30.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 28.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.55
# Class name --> bottle
# Confidence ---> 0.45
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> chair
# Speed: 0.8ms preprocess, 28.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 28.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.63
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> chair
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> bottle
# Speed: 0.8ms preprocess, 28.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 28.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> bottle
# Speed: 0.8ms preprocess, 28.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.45
# Class name --> bottle
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.8ms preprocess, 29.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.54
# Class name --> chair
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.51
# Class name --> bottle
# Speed: 0.9ms preprocess, 29.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 28.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.61
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> chair
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.8ms preprocess, 28.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 28.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.48
# Class name --> bottle
# Confidence ---> 0.44
# Class name --> chair
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 0.8ms preprocess, 28.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 29.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> chair
# Confidence ---> 0.27
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 28.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.55
# Class name --> bottle
# Confidence ---> 0.48
# Class name --> chair
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> bottle
# Speed: 0.8ms preprocess, 28.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 31.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.61
# Class name --> bottle
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.5
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 0.8ms preprocess, 31.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 28.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.59
# Class name --> bottle
# Confidence ---> 0.52
# Class name --> chair
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> bottle
# Speed: 0.9ms preprocess, 28.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 28.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.56
# Class name --> bottle
# Confidence ---> 0.56
# Class name --> bottle
# Confidence ---> 0.55
# Class name --> chair
# Confidence ---> 0.29
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.8ms preprocess, 28.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 29.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.53
# Class name --> bottle
# Confidence ---> 0.48
# Class name --> chair
# Speed: 0.7ms preprocess, 29.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 28.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.66
# Class name --> bottle
# Confidence ---> 0.55
# Class name --> chair
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.45
# Class name --> bottle
# Speed: 0.8ms preprocess, 28.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 28.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.6
# Class name --> bottle
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.41
# Class name --> bottle
# Speed: 0.9ms preprocess, 28.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 28.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 0.9ms preprocess, 28.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 31.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.54
# Class name --> chair
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> bottle
# Speed: 0.8ms preprocess, 31.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 28.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.67
# Class name --> bottle
# Confidence ---> 0.66
# Class name --> bottle
# Confidence ---> 0.54
# Class name --> chair
# Speed: 0.8ms preprocess, 28.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 28.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.44
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> chair
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 0.8ms preprocess, 28.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 31.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.5
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.41
# Class name --> bottle
# Confidence ---> 0.4
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> bottle
# Speed: 0.9ms preprocess, 31.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 29.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.58
# Class name --> bottle
# Confidence ---> 0.44
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> chair
# Speed: 0.8ms preprocess, 29.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 28.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.58
# Class name --> bottle
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.8ms preprocess, 28.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 30.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.4
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> bottle
# Speed: 0.7ms preprocess, 30.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 29.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.45
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> chair
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> bottle
# Speed: 0.9ms preprocess, 29.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 28.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.53
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> chair
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> bottle
# Speed: 0.9ms preprocess, 28.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 31.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.58
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> chair
# Confidence ---> 0.3
# Class name --> bottle
# Speed: 0.9ms preprocess, 31.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 28.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.43
# Class name --> chair
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 0.8ms preprocess, 28.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 23.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> chair
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.8ms preprocess, 23.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 22.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.5
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.35
# Class name --> bottle
# Speed: 0.7ms preprocess, 22.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> chair
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 28.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.7ms preprocess, 28.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 30.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> bottle
# Speed: 0.7ms preprocess, 30.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 29.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.9ms preprocess, 29.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 28.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.48
# Class name --> chair
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> bottle
# Speed: 0.8ms preprocess, 28.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 31.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> chair
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 0.8ms preprocess, 31.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> chair
# Confidence ---> 0.37
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 29.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.44
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> chair
# Speed: 0.8ms preprocess, 29.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 32.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.55
# Class name --> bottle
# Confidence ---> 0.4
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> chair
# Confidence ---> 0.34
# Class name --> bottle
# Speed: 0.8ms preprocess, 32.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.44
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> chair
# Speed: 0.7ms preprocess, 29.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 32.8ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.53
# Class name --> chair
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.8ms preprocess, 32.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 29.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.58
# Class name --> chair
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 30.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.6
# Class name --> chair
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 0.8ms preprocess, 30.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 30.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.56
# Class name --> bottle
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> bottle
# Speed: 0.7ms preprocess, 30.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.56
# Class name --> bottle
# Confidence ---> 0.54
# Class name --> chair
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 32.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 0.8ms preprocess, 32.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 29.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.57
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.45
# Class name --> chair
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 30.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.57
# Class name --> bottle
# Confidence ---> 0.53
# Class name --> chair
# Confidence ---> 0.45
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 0.8ms preprocess, 30.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.61
# Class name --> bottle
# Confidence ---> 0.58
# Class name --> chair
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> bottle
# Speed: 0.7ms preprocess, 29.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.65
# Class name --> bottle
# Confidence ---> 0.62
# Class name --> bottle
# Confidence ---> 0.57
# Class name --> chair
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 0.9ms preprocess, 29.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 20.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.69
# Class name --> bottle
# Confidence ---> 0.63
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.7ms preprocess, 20.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 30.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.63
# Class name --> bottle
# Confidence ---> 0.59
# Class name --> bottle
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> chair
# Speed: 0.8ms preprocess, 30.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 31.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.63
# Class name --> bottle
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.53
# Class name --> chair
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 0.8ms preprocess, 31.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 21.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.58
# Class name --> bottle
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> chair
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 0.7ms preprocess, 21.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 21.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.66
# Class name --> bottle
# Confidence ---> 0.63
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> chair
# Speed: 0.7ms preprocess, 21.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 29.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.55
# Class name --> bottle
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 0.9ms preprocess, 29.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.59
# Class name --> bottle
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.42
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 30.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.63
# Class name --> bottle
# Confidence ---> 0.53
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.8ms preprocess, 30.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 31.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.71
# Class name --> bottle
# Confidence ---> 0.57
# Class name --> bottle
# Confidence ---> 0.45
# Class name --> chair
# Confidence ---> 0.32
# Class name --> bottle
# Speed: 0.8ms preprocess, 31.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 29.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.59
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.43
# Class name --> chair
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 0.9ms preprocess, 29.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 30.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.64
# Class name --> bottle
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> bottle
# Speed: 0.8ms preprocess, 30.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.6
# Class name --> bottle
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 29.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.53
# Class name --> bottle
# Confidence ---> 0.44
# Class name --> bottle
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.33
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.3
# Class name --> bottle
# Speed: 0.9ms preprocess, 29.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.6
# Class name --> bottle
# Confidence ---> 0.55
# Class name --> bottle
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.34
# Class name --> bottle
# Speed: 0.9ms preprocess, 29.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 bottles, 1 chair, 31.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.59
# Class name --> bottle
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 0.8ms preprocess, 31.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 29.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.63
# Class name --> bottle
# Confidence ---> 0.57
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> chair
# Speed: 0.8ms preprocess, 29.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 29.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.73
# Class name --> bottle
# Confidence ---> 0.6
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> chair
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.8ms preprocess, 29.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 bottles, 1 chair, 28.0ms
# ...
# Class name --> person
# Speed: 0.9ms preprocess, 30.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 31.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.1ms preprocess, 34.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.9ms preprocess, 31.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.8ms preprocess, 31.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.9ms preprocess, 30.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.9ms preprocess, 33.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 30.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 33.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.32
# Class name --> chair
# Speed: 0.9ms preprocess, 33.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.9ms preprocess, 32.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 33.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 1.0ms preprocess, 33.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.8ms preprocess, 32.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 30.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.8ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 32.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 32.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.8ms preprocess, 30.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 32.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.9ms preprocess, 32.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.0ms preprocess, 31.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.0ms preprocess, 33.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 32.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.5ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.9ms preprocess, 31.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.0ms preprocess, 30.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 33.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 32.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.33
# Class name --> chair
# Speed: 1.0ms preprocess, 32.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 33.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.36
# Class name --> chair
# Speed: 1.0ms preprocess, 33.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 31.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.34
# Class name --> chair
# Speed: 0.8ms preprocess, 31.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.8ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 29.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 26.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 26.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.9ms preprocess, 22.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.1ms preprocess, 22.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 24.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.9ms preprocess, 24.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.1ms preprocess, 31.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 29.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.9ms preprocess, 29.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 29.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.33
# Class name --> tvmonitor
# Speed: 0.9ms preprocess, 29.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.6ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.0ms preprocess, 30.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.8ms preprocess, 31.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.2ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.9ms preprocess, 33.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.8ms preprocess, 33.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.1ms preprocess, 31.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 30.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 30.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 31.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 31.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.8ms preprocess, 31.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 34.6ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 0.9ms preprocess, 34.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.9ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.9ms preprocess, 32.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 24.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.8ms preprocess, 24.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 25.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 25.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 26.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 26.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.7ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.9ms preprocess, 33.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.9ms preprocess, 32.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 23.7ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.1ms preprocess, 23.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.9ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.1ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.1ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.9ms preprocess, 22.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.5ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 0.9ms preprocess, 22.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.4ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 0.7ms preprocess, 22.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.7ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.0ms preprocess, 31.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.7ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.0ms preprocess, 32.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.8ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 0.9ms preprocess, 33.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.8ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.1ms preprocess, 33.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.6ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.0ms preprocess, 35.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.5ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 0.9ms preprocess, 31.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.7ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.0ms preprocess, 30.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.8ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 0.9ms preprocess, 30.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.2ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.1ms preprocess, 31.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.9ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 0.9ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.3ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.0ms preprocess, 30.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.4ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.0ms preprocess, 32.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.6ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 0.9ms preprocess, 37.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.0ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 0.9ms preprocess, 36.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.1ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.0ms preprocess, 31.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.3ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.9ms preprocess, 31.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.2ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 0.9ms preprocess, 31.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.9ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.0ms preprocess, 33.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.1ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.0ms preprocess, 34.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.5ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.0ms preprocess, 32.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 30.5ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.0ms preprocess, 30.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.7ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.9ms preprocess, 32.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.1ms preprocess, 31.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.7ms preprocess, 31.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.0ms preprocess, 33.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 31.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 31.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 33.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 32.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.9ms preprocess, 32.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 33.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.43
# Class name --> chair
# Speed: 0.9ms preprocess, 33.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 34.2ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.5
# Class name --> chair
# Speed: 0.9ms preprocess, 34.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 34.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.8ms preprocess, 34.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 31.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.34
# Class name --> chair
# Speed: 0.9ms preprocess, 31.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 31.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
# Speed: 0.8ms preprocess, 31.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)

# %%
from ultralytics import YOLO  # Import YOLO model from Ultralytics

import cv2                   # Import OpenCV library
import math                  # Import math module for mathematical operations

# Load the YOLO model
model = YOLO("yolo-Weights/yolov8n.pt")  # Load YOLOv8 model with pre-trained weights

# Define object classes for detection
classNames = [
    "person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
    "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
    "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
    "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
    "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
    "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
    "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
    "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
    "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
    "teddy bear", "hair drier", "toothbrush"
]

def detect_cars(image):
    image_copy = image.copy()
    result = model(image_copy, stream=False)[0]
    boxes = result.boxes  # Extract bounding boxes for detected objects

    # Iterate through each bounding box
    for box in boxes:
        # Extract coordinates of the bounding box
        x1, y1, x2, y2 = box.xyxy[0]
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convert to integer values

        # Draw the bounding box on the frame
        cv2.rectangle(image_copy, (x1, y1), (x2, y2), (255, 0, 255), 3)

        # Overlay class name and confidence
        confidence = math.ceil((box.conf[0]*100))/100
        cls = int(box.cls[0])
        text = f"{classNames[cls]}:{confidence}"

        cv2.putText(
            img=image_copy, 
            text=text, 
            org=[x1, y1], 
            fontFace=cv2.FONT_HERSHEY_SIMPLEX, 
            fontScale=1, 
            color=(255, 0, 0), 
            thickness=2
        )
    
    return image_copy

# %%
from PIL import Image
import numpy as np

image_path = "/home/eonrrfe/Documents/Repos/Others/CarDetection/test_images/cars_0.png"

image = Image.open(image_path)
image.show()
image_array = np.asarray(image)

inferred_image_array = detect_cars(image_array)
inferred_image = Image.fromarray(inferred_image_array)

inferred_image.show()
# Out:
# 0: 640x480 5 cars, 1 suitcase, 31.9ms
# Speed: 1.9ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# <class 'ultralytics.engine.results.Boxes'>
# <class 'ultralytics.engine.results.Boxes'>
# <class 'ultralytics.engine.results.Boxes'>
# <class 'ultralytics.engine.results.Boxes'>
# <class 'ultralytics.engine.results.Boxes'>
# <class 'ultralytics.engine.results.Boxes'>
